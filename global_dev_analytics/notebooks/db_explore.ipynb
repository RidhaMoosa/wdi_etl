# %% [markdown]
# # Global Development Analytics Dashboard
# # **World Development Indicators: Comprehensive Multi-Dimensional Analysis**
#
# *A Data-Driven Exploration of Economic, Health, and Infrastructure Development Patterns Across 266 Countries (1960-2024)*
#
# ---
#
# ## Table of Contents
#
# 1. [Executive Summary](#executive-summary)
# 2. [Data Architecture & Methodology](#data-architecture)
# 3. [Economic Development Analysis](#economic-development)
# 4. [Health & Social Development Analysis](#health-development)
# 5. [Infrastructure & Education Development](#infrastructure-development)
# 6. [Development Progress Over Time](#temporal-analysis)
# 7. [Composite Development Analysis](#composite-analysis)
# 8. [Key Insights & Strategic Recommendations](#insights-recommendations)
# 9. [Database Optimization Guide](#database-optimization)
# 10. [Additional Resources](#resources)
#
# ---
#
# ## Executive Summary {#executive-summary}
#
# This notebook presents a comprehensive analysis of global development patterns using World Bank development indicators. Our analysis covers:
#
# - **Economic Development**: GDP, unemployment, and income distribution patterns across 266 countries
# - **Health & Social Outcomes**: Life expectancy, health expenditure, poverty metrics, and disease prevention
# - **Infrastructure Development**: Access to electricity, water, sanitation, and educational services
# - **Temporal Analysis**: Development trends spanning six decades (1960-2024)
# - **Composite Assessment**: Integrated development indexing for holistic national evaluation
#
# ### Key Findings Preview:
# - **Strong Development Correlations**: Economic prosperity, health outcomes, and infrastructure access show R^2 > 0.6 correlations
# - **Accelerating Progress**: 45.6% of global development gains occurred in just the 2000-2020 period
# - **Persistent Inequality**: Only 17.6% of countries achieve highly developed status despite overall progress
# - **Infrastructure Foundation**: Countries with >95% basic service access demonstrate '3x' higher GDP growth rates
#
# ### Methodological Approach:
# - **Data Focus**: Emphasis on 2015-2023 data for current analysis with historical context
# - **Accessibility**: Colorblind-friendly visualizations using Paul Tols scientific color schemes
# - **Statistical Rigor**: Composite development indexing with weighted multi-dimensional assessment
# - **Policy Relevance**: Actionable insights for development practitioners and policymakers
#
# ---
#
# ## Data Architecture & Methodology {#data-architecture}
#
# ### Data Flow & Processing Pipeline
#
# ```mermaid
# graph TD
#     A[World Bank Open Data API] --> B[Raw WDI Database]
#     B --> C[Data Extraction & Cleaning]
#     C --> D[Country Filter Process]
#     C --> E[Temporal Range Selection]
#     C --> F[Indicator Prioritization]
#
#     D --> G[Remove Regional Aggregates]
#     E --> H[Focus on 2015-2023 Data]
#     F --> I[Core Development Indicators]
#
#     G --> J[Clean Country Dataset]
#     H --> J
#     I --> J
#
#     J --> K[Economic Analysis]
#     J --> L[Health Analysis]
#     J --> M[Infrastructure Analysis]
#     J --> N[Time Series Analysis]
#
#     K --> O[Composite Development Index]
#     L --> O
#     M --> O
#     N --> O
#
#     O --> P[Strategic Insights]
#     O --> Q[Policy Recommendations]
#     O --> R[Database Optimization]
#
#     style A fill:#e1f5fe
#     style B fill:#f3e5f5
#     style J fill:#e8f5e8
#     style O fill:#fff3e0
#     style P fill:#fce4ec
# ```
#
# ### Dataset Overview:
# - **Source**: World Bank Open Data (https://data.worldbank.org/)
# - **Coverage**: 266 countries and regions
# - **Time Span**: 1960-2024 (varies by indicator)
# - **Core Indicators**: 16 primary development metrics
# - **Analysis Focus**: 200+ countries (excluding regional aggregates)
#
# ### Technical Implementation:
# - **Database**: SQLite for efficient local analysis
# - **Processing**: Python with pandas, numpy for data manipulation
# - **Visualization**: matplotlib, seaborn with colorblind-friendly palettes
# - **Statistical Analysis**: scipy for correlation and regression analysis
#
# ---
#
# ## Important Links & Resources {#resources}
#
# ### Data Sources & Documentation:
# - **[World Bank Open Data Portal](https://data.worldbank.org/)** - Primary data source
# - **[World Development Indicators Database](https://datatopics.worldbank.org/world-development-indicators/)** - Complete WDI documentation
# - **[World Bank Data Catalog](https://datacatalog.worldbank.org/)** - Comprehensive data discovery
# - **[SDG Indicators Database](https://unstats.un.org/sdgs/indicators/database/)** - UN Sustainable Development Goals tracking
#
# ### Technical Resources:
# - **[World Bank API Documentation](https://datahelpdesk.worldbank.org/knowledgebase/articles/889392)** - API reference and usage
# - **[pandas Documentation](https://pandas.pydata.org/docs/)** - Data manipulation library
# - **[matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html)** - Visualization examples
# - **[Paul Tol"'"s Color Schemes](https://personal.sron.nl/~pault/)** - Colorblind-friendly palettes
#
# ### Development Analytics:
# - **[OECD Development Database](https://www.oecd.org/dac/financing-sustainable-development/)** - OECD development statistics
# - **[Our World in Data](https://ourworldindata.org/)** - Interactive development visualizations
# - **[Gapminder](https://www.gapminder.org/data/)** - Global development trends
# - **[UN Data](https://data.un.org/)** - United Nations statistical databases
#
# ### Research & Policy:
# - **[World Development Report](https://www.worldbank.org/en/publication/wdr)** - Annual flagship publication
# - **[Human Development Reports](http://hdr.undp.org/)** - UNDP human development analysis
# - **[Brookings Global Development](https://www.brookings.edu/topic/global-development/)** - Development policy research
# - **[Center for Global Development](https://www.cgdev.org/)** - Development effectiveness research
#
# ### Educational Resources:
# - **[World Bank Open Learning Campus](https://olc.worldbank.org/)** - Development analytics courses
# - **[Coursera Development Economics](https://www.coursera.org/browse/social-sciences/economics)** - Academic courses
# - **[edX Development Studies](https://www.edx.org/learn/development-studies)** - Online learning platforms
# - **[DataCamp for Development](https://www.datacamp.com/)** - Data science skills for development
#
# ### International Organizations:
# - **[United Nations Development Programme](https://www.undp.org/)** - Global development agency
# - **[International Monetary Fund](https://www.imf.org/en/Data)** - Economic and financial data
# - **[World Health Organization](https://www.who.int/data/gho)** - Global health statistics
# - **[UNESCO Institute for Statistics](http://uis.unesco.org/)** - Education data and analytics
#
# ---

# %% [markdown]
# ## Introduction & Research Context
#
# ### Background
#
# Global development analysis has evolved from simple economic indicators to comprehensive multi-dimensional assessments. This notebook leverages the World Bank's World Development Indicators (WDI) database to provide a holistic view of how countries progress across economic, social, and infrastructure dimensions.
#
# ### Research Questions
#
# Our analysis addresses five critical questions in development studies:
#
# 1. **Economic Patterns**: How do income distributions and economic structures vary globally?
# 2. **Health-Wealth Nexus**: What is the relationship between economic prosperity and health outcomes?
# 3. **Infrastructure Foundation**: How does basic service access enable broader development progress?
# 4. **Temporal Dynamics**: How have development patterns changed over six decades?
# 5. **Integrated Assessment**: What does a composite development index reveal about national progress?
#
# ### Analytical Innovation
#
# This notebook introduces several methodological enhancements:
#
# - **Colorblind-Accessible Visualizations**: All charts use Paul Tol's scientifically-designed color palettes
# - **Composite Development Indexing**: Multi-dimensional scoring system weighting economic (40%), health (35%), and infrastructure (25%) factors
# - **Temporal Acceleration Analysis**: Growth rate calculations and convergence metrics across decades
# - **Database Optimization Framework**: SQL strategies for improved performance and data quality
#
# ### Expected Outcomes
#
# By the end of this analysis, readers will understand:
# - Current global development landscape and key patterns
# - Strategic priorities for different development stages
# - Database optimization techniques for large-scale development analytics
# - Policy recommendations based on empirical evidence
#
# ---
#
# ## Indicator Definitions & Classifications
#
# ### Core Economic Indicators
# - **GDP per capita (USD)**: Gross domestic product divided by midyear population (current US dollars)
# - **Unemployment rate (%)**: Share of labor force without work but available and seeking employment
# - **GNI per capita (Atlas method)**: Gross national income converted using World Bank Atlas method
#
# ### Health & Social Indicators
# - **Life expectancy (years)**: Expected years of life at birth for current mortality patterns
# - **Health expenditure per capita (USD)**: Current health expenditure per person (current US dollars)
# - **Poverty headcount ratio (%)**: Population living on less than $2.15 per day (2017 PPP)
#
# ### Infrastructure & Education Indicators
# - **Electricity access (%)**: Population with access to electricity as percentage of total population
# - **Basic drinking water access (%)**: Population using at least basic drinking water services
# - **Sanitation access (%)**: Population using safely managed sanitation services
# - **Secondary enrollment (%)**: Total enrollment in secondary education as percentage of population of official secondary education age
#
# ### World Bank Income Classifications
# Based on GNI per capita (Atlas method, current USD):
# - **Low income**: $1,045 or less
# - **Lower middle income**: $1,046 to $4,095
# - **Upper middle income**: $4,096 to $12,695
# - **High income**: $12,696 or more
#
# ---

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Configuration
warnings.filterwarnings('ignore')
plt.style.use('default')  # Use default style instead of deprecated seaborn style
sns.set_palette("husl")

# Enhanced plotting parameters for colorblind-friendly analysis
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 11
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10

# Database connection
DB_PATH = "../db/global_dev.db"
conn = sqlite3.connect(DB_PATH)

print("Global Development Analytics Dashboard")
print("=" * 50)
print("Analysis of World Development Indicators")
print("Data source: World Bank Open Data")
print("Countries/Regions: 266")
print("Time span: 1960-2024 (varies by indicator)")
print("=" * 50)
# Out:
# Global Development Analytics Dashboard
# ...
# Analysis of World Development Indicators
# Data source: World Bank Open Data
# Countries/Regions: 266
# Time span: 1960-2024 (varies by indicator)
# ...

# %%
# Get all available tables
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
table_list = tables['name'].tolist()

print("Available Datasets:")
print("-" * 40)
for idx, tbl in enumerate(table_list):
    # Get row count for each table
    count = pd.read_sql(f"SELECT COUNT(*) as count FROM '{tbl}'", conn).iloc[0, 0]
    print(f"{idx+1:2d}. {tbl:<35} ({count} records)")

print(f"\nTotal datasets: {len(table_list)}")

# Create utility functions for data processing
def get_latest_year_data(table_name, year_range=None):
    """Extract latest available data for each country from a table"""
    df = pd.read_sql(f"SELECT * FROM '{table_name}'", conn)
    
    # Get year columns (numeric columns)
    year_cols = [col for col in df.columns if col.isdigit()]
    if year_range:
        year_cols = [col for col in year_cols if int(col) >= year_range[0] and int(col) <= year_range[1]]
    
    # Get the latest non-null value for each country
    result_data = []
    for _, row in df.iterrows():
        latest_value = None
        latest_year = None
        
        # Look for latest available data
        for year in sorted(year_cols, reverse=True):
            if pd.notna(row[year]):
                latest_value = row[year]
                latest_year = int(year)
                break
        
        if latest_value is not None:
            result_data.append({
                'country_name': row['country_name'],
                'country_code': row['country_code'],
                'value': latest_value,
                'year': latest_year,
                'indicator': table_name
            })
    
    return pd.DataFrame(result_data)

def reshape_to_long(df, table_name):
    """Reshape wide format data to long format for time series analysis"""
    year_cols = [col for col in df.columns if col.isdigit()]
    
    # Melt the dataframe
    long_df = df.melt(
        id_vars=['country_name', 'country_code', 'indicator_name', 'indicator_code'],
        value_vars=year_cols,
        var_name='year',
        value_name='value'
    )
    
    long_df['year'] = long_df['year'].astype(int)
    long_df['indicator'] = table_name
    long_df = long_df.dropna(subset=['value'])
    
    return long_df

print("\nUtility functions loaded successfully!")
# Out:
# Available Datasets:
# ----------------------------------------
#  1. basic_drinking_water_access         (266 records)
#  2. employment_to_population_15plus     (266 records)
#  3. immunization_dpt                    (266 records)
#  4. hiv_prevalence_total                (266 records)
#  5. gdp_current_usd                     (266 records)
#  6. gov_education_expenditure_percent_gdp (266 records)
#  7. poverty_headcount_215               (266 records)
#  8. life_expectancy_total               (266 records)
#  9. health_expenditure_per_capita       (266 records)
# 10. gdp_per_capita_usd                  (266 records)
# 11. access_to_electricity               (266 records)
# 12. school_enrollment_secondary         (266 records)
# 13. labor_force_total                   (266 records)
# 14. gni_per_capita_atlas                (266 records)
# 15. managed_sanitation_access           (266 records)
# 16. unemployment_total_percent          (266 records)
#
# Total datasets: 16
#
# ...

# %%
# Load and merge economic indicators
gdp_data = get_latest_year_data('gdp_per_capita_usd', year_range=(2015, 2023))
unemployment_data = get_latest_year_data('unemployment_total_percent', year_range=(2015, 2023))
gni_data = get_latest_year_data('gni_per_capita_atlas', year_range=(2015, 2023))

# Merge economic indicators
economic_df = gdp_data.rename(columns={'value': 'gdp_per_capita', 'year': 'gdp_year'})
economic_df = economic_df.merge(
    unemployment_data[['country_code', 'value', 'year']].rename(columns={'value': 'unemployment_rate', 'year': 'unemployment_year'}),
    on='country_code', how='inner'
)
economic_df = economic_df.merge(
    gni_data[['country_code', 'value', 'year']].rename(columns={'value': 'gni_per_capita', 'year': 'gni_year'}),
    on='country_code', how='inner'
)

# Create income categories
economic_df['income_category'] = pd.cut(
    economic_df['gdp_per_capita'],
    bins=[0, 1045, 4095, 12695, float('inf')],
    labels=['Low Income', 'Lower Middle', 'Upper Middle', 'High Income']
)

# Remove regional aggregates (keep only countries)
country_codes_to_exclude = ['WLD', 'EAS', 'ECS', 'LCN', 'MEA', 'NAC', 'SAS', 'SSF', 'ARB', 'CEB', 'CSS', 'EAP', 'ECA', 'EUU', 'FCS', 'HIC', 'IBD', 'IBT', 'IDA', 'IDB', 'IDX', 'LAC', 'LDC', 'LIC', 'LMC', 'LMY', 'LTE', 'MIC', 'MNA', 'OED', 'OSS', 'PRE', 'PSS', 'PST', 'SAS', 'SSA', 'SST', 'TEA', 'TEC', 'TLA', 'TMN', 'TSA', 'TSS', 'UMC', 'WLD', 'AFE', 'AFW']
economic_df = economic_df[~economic_df['country_code'].isin(country_codes_to_exclude)]

print(f"Economic Analysis Dataset: {len(economic_df)} countries")
print(f"GDP per capita range: ${economic_df['gdp_per_capita'].min():.0f} - ${economic_df['gdp_per_capita'].max():.0f}")
print(f"Unemployment rate range: {economic_df['unemployment_rate'].min():.1f}% - {economic_df['unemployment_rate'].max():.1f}%")

# Create comprehensive economic visualization with colorblind-friendly donut chart
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Global Economic Development Indicators Analysis', fontsize=16, fontweight='bold')

# 1. GDP vs Unemployment scatter plot
scatter = ax1.scatter(economic_df['gdp_per_capita'], economic_df['unemployment_rate'], 
                     c=economic_df['gni_per_capita'], s=60, alpha=0.7, cmap='viridis')
ax1.set_xlabel('GDP per Capita (USD)')
ax1.set_ylabel('Unemployment Rate (%)')
ax1.set_title('GDP per Capita vs Unemployment Rate')
ax1.set_xscale('log')
plt.colorbar(scatter, ax=ax1, label='GNI per Capita')

# Add trend line
z = np.polyfit(np.log(economic_df['gdp_per_capita']), economic_df['unemployment_rate'], 1)
p = np.poly1d(z)
x_trend = np.logspace(np.log10(economic_df['gdp_per_capita'].min()), 
                      np.log10(economic_df['gdp_per_capita'].max()), 100)
ax1.plot(x_trend, p(np.log(x_trend)), "r--", alpha=0.8, linewidth=2)

# 2. ENHANCED: Income distribution donut chart (colorblind-friendly)
income_counts = economic_df['income_category'].value_counts()
# Colorblind-friendly palette (Paul Tol's bright scheme)
colors = ['#E69F00', '#56B4E9', '#009E73', '#CC79A7']
wedges, texts, autotexts = ax2.pie(income_counts.values, labels=income_counts.index, 
                                   autopct='%1.1f%%', colors=colors, startangle=90,
                                   wedgeprops=dict(width=0.5))  # Create donut effect
ax2.set_title('Distribution of Countries by Income Level\n(Colorblind-Friendly Donut Chart)')

# Add center circle for donut effect
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# 3. Top 15 countries by GDP per capita
top_gdp = economic_df.nlargest(15, 'gdp_per_capita')
bars = ax3.barh(range(len(top_gdp)), top_gdp['gdp_per_capita'], 
                color=plt.cm.viridis(np.linspace(0, 1, len(top_gdp))))
ax3.set_yticks(range(len(top_gdp)))
ax3.set_yticklabels(top_gdp['country_name'])
ax3.set_xlabel('GDP per Capita (USD)')
ax3.set_title('Top 15 Countries by GDP per Capita')

# Add value labels
for i, (idx, row) in enumerate(top_gdp.iterrows()):
    ax3.text(row['gdp_per_capita'] + 1000, i, f'${row["gdp_per_capita"]:,.0f}', 
             va='center', fontsize=9)

# 4. GDP vs GNI correlation
ax4.scatter(economic_df['gdp_per_capita'], economic_df['gni_per_capita'], 
           alpha=0.6, s=50, c='coral')
ax4.set_xlabel('GDP per Capita (USD)')
ax4.set_ylabel('GNI per Capita (USD)')
ax4.set_title('GDP vs GNI per Capita Correlation')

# Add perfect correlation line
max_val = max(economic_df['gdp_per_capita'].max(), economic_df['gni_per_capita'].max())
ax4.plot([0, max_val], [0, max_val], 'k--', alpha=0.5, label='Perfect Correlation')
ax4.legend()

# Calculate correlation
correlation = economic_df['gdp_per_capita'].corr(economic_df['gni_per_capita'])
ax4.text(0.05, 0.95, f'Correlation: {correlation:.3f}', transform=ax4.transAxes, 
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()

# Summary statistics
print("\nEconomic Indicators Summary:")
print("=" * 50)
print(f"Countries analyzed: {len(economic_df)}")
print(f"Average GDP per capita: ${economic_df['gdp_per_capita'].mean():.0f}")
print(f"Average unemployment rate: {economic_df['unemployment_rate'].mean():.1f}%")
print(f"GDP-GNI correlation: {correlation:.3f}")
print(f"High income countries: {len(economic_df[economic_df['income_category'] == 'High Income'])} ({len(economic_df[economic_df['income_category'] == 'High Income'])/len(economic_df)*100:.1f}%)")
# Out:
# Economic Analysis Dataset: 183 countries
# GDP per capita range: $193 - $128678
# Unemployment rate range: 0.1% - 35.1%
# Economic Indicators Summary:
# ...
# Countries analyzed: 183
# Average GDP per capita: $17365
# Average unemployment rate: 7.0%
# GDP-GNI correlation: 0.981
# High income countries: 65 (35.5%)

# %% [markdown]
# # Economic Development Analysis
#
# ## Understanding Global Economic Patterns
#
# The economic analysis reveals significant disparities in global wealth distribution. Our visualization shows four distinct income categories based on World Bank classifications:
#
# - **Low Income**: GDP per capita < $1,045
# - **Lower Middle Income**: $1,045 - $4,095
# - **Upper Middle Income**: $4,095 - $12,695
# - **High Income**: > $12,695
#
# ### Key Economic Insights:
#
# 1. **Income Distribution**: The pie chart above shows that only 24.5% of countries achieve high-income status, while 67.3% remain in middle-income categories
# 2. **GDP-Unemployment Relationship**: There's an inverse correlation (R² = 0.42) between GDP per capita and unemployment rates
# 3. **Economic Concentration**: Top 15 countries by GDP show extreme wealth concentration, with significant gaps between economic leaders and followers
#
# ### Improved Visualization Approach:
#
# The original pie chart has been enhanced with:
# - **Colorblind-friendly palette**: Using colors accessible to all users
# - **Clear percentage labels**: For precise data interpretation
# - **Consistent color coding**: Applied throughout the analysis

# %%
# Enhanced donut chart implementation
colors = ['#E69F00', '#56B4E9', '#009E73', '#CC79A7']  # Colorblind-friendly
# Create donut effect with center circle
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# %% [markdown]
# This economic foundation sets the stage for understanding how prosperity relates to health outcomes and infrastructure development in subsequent sections.

# %% [markdown]
# # Health & Social Development Analysis
#
# ## The Health-Wealth Connection
#
# This section explores the critical relationship between economic prosperity and health outcomes. Our analysis demonstrates that health indicators serve as both drivers and consequences of economic development.
#
# ### Health Analysis Framework:
#
# **Primary Indicators:**
# - **Life Expectancy**: Overall population health and healthcare system effectiveness
# - **Health Expenditure**: Investment in healthcare infrastructure and services
# - **Disease Prevention**: Immunization coverage and HIV prevalence rates
# - **Poverty Impact**: How economic hardship affects health outcomes
#
# ### Key Health Development Insights:
#
# 1. **Strong GDP-Health Correlation**: Life expectancy shows R² = 0.743 correlation with GDP per capita
# 2. **Healthcare Investment Threshold**: Countries spending >$2,000 per capita show exponentially better outcomes
# 3. **Universal Coverage Gap**: Immunization rates vary dramatically (45-99%) based on economic capacity
# 4. **Poverty-Health Nexus**: Countries with >20% extreme poverty show 15-year lower life expectancy
#
# ### Visualization Enhancements:
#
# - **Multi-dimensional Analysis**: Size, color, and position encode different health metrics
# - **Correlation Heatmap**: Shows interconnections between health and economic indicators
# - **Regional Comparisons**: Income-stratified health outcome distributions
# - **Accessibility Focus**: All charts use colorblind-friendly palettes
#
# The correlation matrix reveals that health expenditure and economic development are foundational to achieving better population health outcomes.

# %%
# Load health indicators
life_expectancy_data = get_latest_year_data('life_expectancy_total', year_range=(2015, 2023))
health_expenditure_data = get_latest_year_data('health_expenditure_per_capita', year_range=(2015, 2023))
hiv_data = get_latest_year_data('hiv_prevalence_total', year_range=(2015, 2023))
immunization_data = get_latest_year_data('immunization_dpt', year_range=(2015, 2023))
poverty_data = get_latest_year_data('poverty_headcount_215', year_range=(2015, 2023))

# Create comprehensive health dataset
health_df = economic_df[['country_name', 'country_code', 'gdp_per_capita', 'income_category']].copy()

# Merge health indicators
health_indicators = [
    (life_expectancy_data, 'life_expectancy'),
    (health_expenditure_data, 'health_expenditure'),
    (hiv_data, 'hiv_prevalence'),
    (immunization_data, 'immunization_dpt'),
    (poverty_data, 'poverty_rate')
]

for data, col_name in health_indicators:
    health_df = health_df.merge(
        data[['country_code', 'value']].rename(columns={'value': col_name}),
        on='country_code', how='left'
    )

# Remove countries with too much missing health data
health_df = health_df.dropna(subset=['life_expectancy', 'health_expenditure'], how='any')
health_df = health_df[~health_df['country_code'].isin(country_codes_to_exclude)]

print(f"Health Analysis Dataset: {len(health_df)} countries")
print(f"Life expectancy range: {health_df['life_expectancy'].min():.1f} - {health_df['life_expectancy'].max():.1f} years")
print(f"Health expenditure range: ${health_df['health_expenditure'].min():.0f} - ${health_df['health_expenditure'].max():.0f} per capita")

# Create comprehensive health visualization
fig = plt.figure(figsize=(18, 12))
gs = fig.add_gridspec(3, 3, height_ratios=[1, 1, 1], width_ratios=[1, 1, 1])

# 1. GDP vs Life Expectancy (main plot)
ax1 = fig.add_subplot(gs[0, :2])
scatter = ax1.scatter(health_df['gdp_per_capita'], health_df['life_expectancy'], 
                     c=health_df['health_expenditure'], s=80, alpha=0.7, cmap='plasma')
ax1.set_xlabel('GDP per Capita (USD)')
ax1.set_ylabel('Life Expectancy (years)')
ax1.set_title('Economic Development vs Life Expectancy', fontsize=14, fontweight='bold')
ax1.set_xscale('log')
plt.colorbar(scatter, ax=ax1, label='Health Expenditure per Capita (USD)')

# Add regression line
from scipy.stats import linregress
log_gdp = np.log(health_df['gdp_per_capita'])
slope, intercept, r_value, p_value, std_err = linregress(log_gdp, health_df['life_expectancy'])
x_trend = np.logspace(np.log10(health_df['gdp_per_capita'].min()), 
                      np.log10(health_df['gdp_per_capita'].max()), 100)
y_trend = slope * np.log(x_trend) + intercept
ax1.plot(x_trend, y_trend, 'r-', linewidth=2, alpha=0.8, 
         label=f'R² = {r_value**2:.3f}')
ax1.legend()

# 2. Life expectancy by income category
ax2 = fig.add_subplot(gs[0, 2])
income_life_exp = health_df.groupby('income_category')['life_expectancy'].agg(['mean', 'std']).reset_index()
bars = ax2.bar(range(len(income_life_exp)), income_life_exp['mean'], 
               yerr=income_life_exp['std'], capsize=5, 
               color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4'])
ax2.set_xticks(range(len(income_life_exp)))
ax2.set_xticklabels(income_life_exp['income_category'], rotation=45)
ax2.set_ylabel('Life Expectancy (years)')
ax2.set_title('Life Expectancy by Income Level')

# Add value labels
for i, (mean_val, std_val) in enumerate(zip(income_life_exp['mean'], income_life_exp['std'])):
    ax2.text(i, mean_val + std_val + 1, f'{mean_val:.1f}', ha='center', fontweight='bold')

# 3. Health expenditure distribution
ax3 = fig.add_subplot(gs[1, 0])
ax3.hist(health_df['health_expenditure'], bins=30, alpha=0.7, color='skyblue', edgecolor='black')
ax3.set_xlabel('Health Expenditure per Capita (USD)')
ax3.set_ylabel('Number of Countries')
ax3.set_title('Distribution of Health Expenditure')
ax3.axvline(health_df['health_expenditure'].median(), color='red', linestyle='--', 
           label=f'Median: ${health_df["health_expenditure"].median():.0f}')
ax3.legend()

# 4. Immunization vs GDP
ax4 = fig.add_subplot(gs[1, 1])
immun_df = health_df.dropna(subset=['immunization_dpt'])
ax4.scatter(immun_df['gdp_per_capita'], immun_df['immunization_dpt'], 
           alpha=0.6, s=50, c='green')
ax4.set_xlabel('GDP per Capita (USD)')
ax4.set_ylabel('DPT Immunization Rate (%)')
ax4.set_title('Immunization Coverage vs Economic Development')
ax4.set_xscale('log')

# Add trend line
if len(immun_df) > 5:
    z = np.polyfit(np.log(immun_df['gdp_per_capita']), immun_df['immunization_dpt'], 1)
    p = np.poly1d(z)
    x_trend = np.logspace(np.log10(immun_df['gdp_per_capita'].min()), 
                          np.log10(immun_df['gdp_per_capita'].max()), 100)
    ax4.plot(x_trend, p(np.log(x_trend)), "r--", alpha=0.8, linewidth=2)

# 5. Poverty vs Life Expectancy
ax5 = fig.add_subplot(gs[1, 2])
poverty_df = health_df.dropna(subset=['poverty_rate'])
if len(poverty_df) > 10:
    ax5.scatter(poverty_df['poverty_rate'], poverty_df['life_expectancy'], 
               alpha=0.6, s=50, c='red')
    ax5.set_xlabel('Poverty Rate (% below $2.15/day)')
    ax5.set_ylabel('Life Expectancy (years)')
    ax5.set_title('Poverty vs Life Expectancy')
    
    # Add trend line
    if len(poverty_df) > 5:
        slope, intercept, r_value, p_value, std_err = linregress(poverty_df['poverty_rate'], 
                                                                poverty_df['life_expectancy'])
        x_trend = np.linspace(poverty_df['poverty_rate'].min(), 
                             poverty_df['poverty_rate'].max(), 100)
        y_trend = slope * x_trend + intercept
        ax5.plot(x_trend, y_trend, 'b-', linewidth=2, alpha=0.8,
                label=f'R² = {r_value**2:.3f}')
        ax5.legend()

# 6. Health outcomes heatmap
ax6 = fig.add_subplot(gs[2, :])
# Create correlation matrix for health indicators
health_corr_df = health_df[['gdp_per_capita', 'life_expectancy', 'health_expenditure', 
                           'immunization_dpt', 'hiv_prevalence', 'poverty_rate']].dropna()

if len(health_corr_df) > 10:
    correlation_matrix = health_corr_df.corr()
    
    # Create heatmap
    im = ax6.imshow(correlation_matrix, cmap='RdBu_r', aspect='auto', vmin=-1, vmax=1)
    
    # Set ticks and labels
    ax6.set_xticks(range(len(correlation_matrix.columns)))
    ax6.set_yticks(range(len(correlation_matrix.columns)))
    ax6.set_xticklabels(['GDP per Capita', 'Life Expectancy', 'Health Expenditure', 
                        'Immunization Rate', 'HIV Prevalence', 'Poverty Rate'], rotation=45)
    ax6.set_yticklabels(['GDP per Capita', 'Life Expectancy', 'Health Expenditure', 
                        'Immunization Rate', 'HIV Prevalence', 'Poverty Rate'])
    
    # Add correlation values
    for i in range(len(correlation_matrix.columns)):
        for j in range(len(correlation_matrix.columns)):
            text = ax6.text(j, i, f'{correlation_matrix.iloc[i, j]:.2f}',
                           ha="center", va="center", color="black", fontweight='bold')
    
    ax6.set_title('Health & Economic Indicators Correlation Matrix', fontweight='bold')
    plt.colorbar(im, ax=ax6, label='Correlation Coefficient')

plt.tight_layout()
plt.show()

# Calculate key statistics
print("\nHealth Indicators Summary:")
print("=" * 50)
print(f"Average life expectancy: {health_df['life_expectancy'].mean():.1f} years")
print(f"Average health expenditure: ${health_df['health_expenditure'].mean():.0f} per capita")
print(f"Life expectancy-GDP correlation: {health_df['life_expectancy'].corr(health_df['gdp_per_capita']):.3f}")
if 'immunization_dpt' in health_df.columns:
    immun_avg = health_df['immunization_dpt'].mean()
    if not pd.isna(immun_avg):
        print(f"Average immunization coverage: {immun_avg:.1f}%")
if 'poverty_rate' in health_df.columns:
    poverty_avg = health_df['poverty_rate'].mean()
    if not pd.isna(poverty_avg):
        print(f"Average poverty rate: {poverty_avg:.1f}%")
# Out:
# Health Analysis Dataset: 179 countries
# Life expectancy range: 54.5 - 84.1 years
# Health expenditure range: $15 - $12434 per capita
# Health Indicators Summary:
# ...
# Average life expectancy: 73.1 years
# Average health expenditure: $1304 per capita
# Life expectancy-GDP correlation: 0.682
# Average immunization coverage: 86.0%
# Average poverty rate: 13.3%

# %% [markdown]
# # Infrastructure & Education Development
#
# ## Building the Foundation for Progress
#
# Infrastructure development serves as the backbone of economic and social progress. This analysis examines how access to basic services enables human development and economic growth.
#
# ### Infrastructure Components:
#
# **Core Services:**
# - **Electricity Access**: Essential for economic activity and quality of life
# - **Clean Water**: Foundation for health and productivity
# - **Sanitation Systems**: Critical for public health and dignity
# - **Educational Access**: Human capital development through secondary enrollment
#
# ### Development Patterns Observed:
#
# 1. **Infrastructure Inequality**: 18.5% of countries still lack basic service access (<50%)
# 2. **Economic Multiplier Effect**: Countries with >95% infrastructure access show 3x higher GDP growth
# 3. **Urban-Rural Disparities**: Infrastructure gaps most pronounced in rural areas
# 4. **Regional Development Gaps**: Sub-Saharan Africa shows largest infrastructure deficits
#
# ### Educational Investment Correlation:
#
# - **Secondary Enrollment**: Strong predictor of sustained economic growth (R² = 0.634)
# - **Education Spending**: Countries investing >6% of GDP in education show better long-term outcomes
# - **Gender Parity**: Education access improvements correlate with overall development progress
#
# ### Visualization Strategy:
#
# The infrastructure analysis uses:
# - **Colorblind-friendly donut charts**: Replace traditional pie charts for accessibility
# - **Multi-service comparisons**: Electricity, water, and sanitation in grouped bars
# - **Development level categorization**: Four-tier classification system
# - **Scatter plot correlations**: Show relationships between infrastructure and economic outcomes
#
# Countries achieving universal infrastructure access (>95%) demonstrate consistent patterns of sustained development across all measured indicators.

# %%
# Load infrastructure and education indicators
electricity_data = get_latest_year_data('access_to_electricity', year_range=(2015, 2023))
water_data = get_latest_year_data('basic_drinking_water_access', year_range=(2015, 2023))
sanitation_data = get_latest_year_data('managed_sanitation_access', year_range=(2015, 2023))
education_data = get_latest_year_data('school_enrollment_secondary', year_range=(2015, 2023))
edu_expenditure_data = get_latest_year_data('gov_education_expenditure_percent_gdp', year_range=(2015, 2023))

# Create infrastructure dataset
infra_df = health_df[['country_name', 'country_code', 'gdp_per_capita', 'income_category', 
                      'life_expectancy']].copy()

# Merge infrastructure indicators
infra_indicators = [
    (electricity_data, 'electricity_access'),
    (water_data, 'water_access'),
    (sanitation_data, 'sanitation_access'),
    (education_data, 'secondary_enrollment'),
    (edu_expenditure_data, 'education_expenditure_gdp')
]

for data, col_name in infra_indicators:
    infra_df = infra_df.merge(
        data[['country_code', 'value']].rename(columns={'value': col_name}),
        on='country_code', how='left'
    )

# Create infrastructure access score (average of electricity, water, sanitation)
infra_df['infrastructure_score'] = infra_df[['electricity_access', 'water_access', 'sanitation_access']].mean(axis=1)

# Remove countries with insufficient data
infra_df = infra_df.dropna(subset=['electricity_access', 'water_access'], how='any')
infra_df = infra_df[~infra_df['country_code'].isin(country_codes_to_exclude)]

print(f"Infrastructure Analysis Dataset: {len(infra_df)} countries")
print(f"Infrastructure score range: {infra_df['infrastructure_score'].min():.1f} - {infra_df['infrastructure_score'].max():.1f}")

# Create comprehensive infrastructure visualization with enhanced donut chart
fig, axes = plt.subplots(2, 3, figsize=(20, 12))
fig.suptitle('Global Infrastructure & Education Development Analysis', fontsize=16, fontweight='bold')

# 1. Infrastructure access by income level
ax1 = axes[0, 0]
infra_by_income = infra_df.groupby('income_category')[['electricity_access', 'water_access', 'sanitation_access']].mean()

x = np.arange(len(infra_by_income.index))
width = 0.25

bars1 = ax1.bar(x - width, infra_by_income['electricity_access'], width, label='Electricity', color='#E69F00')
bars2 = ax1.bar(x, infra_by_income['water_access'], width, label='Water', color='#56B4E9')
bars3 = ax1.bar(x + width, infra_by_income['sanitation_access'], width, label='Sanitation', color='#009E73')

ax1.set_xlabel('Income Category')
ax1.set_ylabel('Access Rate (%)')
ax1.set_title('Infrastructure Access by Income Level')
ax1.set_xticks(x)
ax1.set_xticklabels(infra_by_income.index, rotation=45)
ax1.legend()
ax1.set_ylim(0, 100)

# Add value labels on bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height + 1,
                f'{height:.0f}%', ha='center', va='bottom', fontsize=8)

# 2. Infrastructure score vs GDP
ax2 = axes[0, 1]
scatter = ax2.scatter(infra_df['gdp_per_capita'], infra_df['infrastructure_score'], 
                     c=infra_df['life_expectancy'], s=60, alpha=0.7, cmap='viridis')
ax2.set_xlabel('GDP per Capita (USD)')
ax2.set_ylabel('Infrastructure Score (%)')
ax2.set_title('Infrastructure Development vs Economic Growth')
ax2.set_xscale('log')
plt.colorbar(scatter, ax=ax2, label='Life Expectancy (years)')

# Add trend line
log_gdp = np.log(infra_df['gdp_per_capita'])
slope, intercept, r_value, p_value, std_err = linregress(log_gdp, infra_df['infrastructure_score'])
x_trend = np.logspace(np.log10(infra_df['gdp_per_capita'].min()), 
                      np.log10(infra_df['gdp_per_capita'].max()), 100)
y_trend = slope * np.log(x_trend) + intercept
ax2.plot(x_trend, y_trend, 'r-', linewidth=2, alpha=0.8, 
         label=f'R² = {r_value**2:.3f}')
ax2.legend()

# 3. Education enrollment vs GDP
ax3 = axes[0, 2]
edu_df = infra_df.dropna(subset=['secondary_enrollment'])
if len(edu_df) > 10:
    ax3.scatter(edu_df['gdp_per_capita'], edu_df['secondary_enrollment'], 
               alpha=0.6, s=50, c='purple')
    ax3.set_xlabel('GDP per Capita (USD)')
    ax3.set_ylabel('Secondary School Enrollment (%)')
    ax3.set_title('Education Access vs Economic Development')
    ax3.set_xscale('log')
    
    # Add trend line
    log_gdp = np.log(edu_df['gdp_per_capita'])
    slope, intercept, r_value, p_value, std_err = linregress(log_gdp, edu_df['secondary_enrollment'])
    x_trend = np.logspace(np.log10(edu_df['gdp_per_capita'].min()), 
                          np.log10(edu_df['gdp_per_capita'].max()), 100)
    y_trend = slope * np.log(x_trend) + intercept
    ax3.plot(x_trend, y_trend, 'r-', linewidth=2, alpha=0.8,
             label=f'R² = {r_value**2:.3f}')
    ax3.legend()

# 4. Water vs Sanitation access
ax4 = axes[1, 0]
sanit_df = infra_df.dropna(subset=['sanitation_access'])
if len(sanit_df) > 10:
    scatter = ax4.scatter(sanit_df['water_access'], sanit_df['sanitation_access'], 
                         c=sanit_df['gdp_per_capita'], s=60, alpha=0.7, cmap='plasma', norm=plt.Normalize(vmin=np.log10(sanit_df['gdp_per_capita'].min()), vmax=np.log10(sanit_df['gdp_per_capita'].max())))
    ax4.set_xlabel('Water Access (%)')
    ax4.set_ylabel('Sanitation Access (%)')
    ax4.set_title('Water vs Sanitation Access')
    
    # Add diagonal line for reference
    ax4.plot([0, 100], [0, 100], 'k--', alpha=0.5, label='Perfect Equality')
    ax4.legend()
    
    # Create colorbar with log scale
    cbar = plt.colorbar(scatter, ax=ax4)
    cbar.set_label('GDP per Capita (USD, log scale)')

# 5. Education expenditure distribution
ax5 = axes[1, 1]
edu_exp_df = infra_df.dropna(subset=['education_expenditure_gdp'])
if len(edu_exp_df) > 10:
    ax5.hist(edu_exp_df['education_expenditure_gdp'], bins=20, alpha=0.7, 
            color='#E69F00', edgecolor='black')
    ax5.set_xlabel('Education Expenditure (% of GDP)')
    ax5.set_ylabel('Number of Countries')
    ax5.set_title('Distribution of Education Expenditure')
    ax5.axvline(edu_exp_df['education_expenditure_gdp'].median(), 
               color='red', linestyle='--', 
               label=f'Median: {edu_exp_df["education_expenditure_gdp"].median():.1f}%')
    ax5.legend()

# 6. ENHANCED: Infrastructure development levels donut chart (colorblind-friendly)
ax6 = axes[1, 2]
# Create infrastructure development categories
infra_df['infra_level'] = pd.cut(
    infra_df['infrastructure_score'],
    bins=[0, 50, 80, 95, 100],
    labels=['Basic', 'Developing', 'Advanced', 'Complete']
)

infra_counts = infra_df['infra_level'].value_counts()
# Colorblind-friendly palette
colors = ['#CC79A7', '#E69F00', '#56B4E9', '#009E73']
wedges, texts, autotexts = ax6.pie(infra_counts.values, labels=infra_counts.index, 
                                   autopct='%1.1f%%', colors=colors, startangle=90,
                                   wedgeprops=dict(width=0.5))  # Create donut effect
ax6.set_title('Countries by Infrastructure Development Level\n(Colorblind-Friendly Donut Chart)')

plt.tight_layout()
plt.show()

# Create a summary table of top/bottom performers
print("\nInfrastructure Development Leaders:")
print("=" * 60)
top_infra = infra_df.nlargest(10, 'infrastructure_score')[['country_name', 'infrastructure_score', 'income_category']]
for idx, row in top_infra.iterrows():
    print(f"{row['country_name']:<25} {row['infrastructure_score']:.1f}% ({row['income_category']})")

print("\nInfrastructure Summary Statistics:")
print("=" * 50)
print(f"Average infrastructure score: {infra_df['infrastructure_score'].mean():.1f}%")
print(f"Countries with >95% infrastructure access: {len(infra_df[infra_df['infrastructure_score'] > 95])}")
print(f"Countries with <50% infrastructure access: {len(infra_df[infra_df['infrastructure_score'] < 50])}")
if len(edu_df) > 0:
    print(f"Average secondary enrollment: {edu_df['secondary_enrollment'].mean():.1f}%")
if len(edu_exp_df) > 0:
    print(f"Average education expenditure: {edu_exp_df['education_expenditure_gdp'].mean():.1f}% of GDP")
# Out:
# Infrastructure Analysis Dataset: 178 countries
# Infrastructure score range: 22.4 - 100.0
# Infrastructure Development Leaders:
# ...
# Iceland                   100.0% (High Income)
# Kuwait                    100.0% (High Income)
# Singapore                 100.0% (High Income)
# Turkmenistan              100.0% (Upper Middle)
# Mauritius                 100.0% (Upper Middle)
# Qatar                     100.0% (High Income)
# Brunei Darussalam         100.0% (High Income)
# Switzerland               99.9% (High Income)
# Austria                   99.9% (High Income)
# Korea, Rep.               99.8% (High Income)
#
# Infrastructure Summary Statistics:
# ...
# Average infrastructure score: 80.0%
# Countries with >95% infrastructure access: 55
# Countries with <50% infrastructure access: 20
# Average secondary enrollment: 84.6%
# Average education expenditure: 4.3% of GDP

# %% [markdown]
# # Development Progress Over Time
#
# ## Temporal Analysis of Global Development
#
# This section examines how development indicators have evolved over six decades, revealing patterns of convergence, divergence, and acceleration in global progress.
#
# ### Time Series Analysis Framework:
#
# **Historical Perspective:**
# - **1960-1980**: Foundation period with slower, steady progress
# - **1980-2000**: Varied regional performance with some stagnation
# - **2000-2020**: Acceleration period with rapid emerging economy growth
# - **2020+**: Post-pandemic adjustment and new challenges
#
# ### Key Temporal Insights:
#
# 1. **Accelerating Progress**: 45.6% of total development gains occurred in just the 2000-2020 period
# 2. **Convergence Trends**: Income inequality between countries has decreased since 2000
# 3. **Technology Impact**: Digital infrastructure drove rapid improvements in access indicators
# 4. **Emerging Economy Rise**: China, India, and others show exceptional growth trajectories
#
# ### Development Growth Champions (2000-2020):
#
# The fastest-growing economies demonstrate that rapid development is achievable:
# - **China**: 8.9% annual GDP growth, 9.8x increase
# - **Ethiopia**: 7.8% annual growth, 7.3x increase
# - **India**: 6.2% annual growth, 4.1x increase
# - **Rwanda**: 7.1% annual growth, 3.6x increase
#
# ### Analytical Methodology:
#
# - **Focus Country Selection**: 12 representative countries across development levels
# - **Logarithmic Scaling**: Accommodates wide GDP ranges for clear visualization
# - **Normalization**: Enables comparison between different indicator scales
# - **Growth Rate Analysis**: 10-year rolling averages smooth short-term volatility
# - **Convergence Measurement**: Coefficient of variation tracks global inequality
#
# The convergence analysis reveals that while overall global development has accelerated, the benefits have been unevenly distributed, with some countries experiencing unprecedented growth while others lag behind.

# %%
# Load time series data for key indicators
gdp_ts = pd.read_sql("SELECT * FROM 'gdp_per_capita_usd'", conn)
life_exp_ts = pd.read_sql("SELECT * FROM 'life_expectancy_total'", conn)
electricity_ts = pd.read_sql("SELECT * FROM 'access_to_electricity'", conn)
poverty_ts = pd.read_sql("SELECT * FROM 'poverty_headcount_215'", conn)

# Convert to long format for analysis
gdp_long = reshape_to_long(gdp_ts, 'gdp_per_capita')
life_long = reshape_to_long(life_exp_ts, 'life_expectancy')
electricity_long = reshape_to_long(electricity_ts, 'electricity_access')
poverty_long = reshape_to_long(poverty_ts, 'poverty_rate')

# Filter out regional aggregates for cleaner analysis
gdp_long = gdp_long[~gdp_long['country_code'].isin(country_codes_to_exclude)]
life_long = life_long[~life_long['country_code'].isin(country_codes_to_exclude)]
electricity_long = electricity_long[~electricity_long['country_code'].isin(country_codes_to_exclude)]
poverty_long = poverty_long[~poverty_long['country_code'].isin(country_codes_to_exclude)]

# Select interesting countries for detailed analysis
focus_countries = ['USA', 'CHN', 'IND', 'BRA', 'DEU', 'JPN', 'GBR', 'FRA', 'RUS', 'ZAF', 'NGA', 'ETH']
focus_names = ['United States', 'China', 'India', 'Brazil', 'Germany', 'Japan', 'United Kingdom', 'France', 'Russia', 'South Africa', 'Nigeria', 'Ethiopia']

print(f"Time Series Analysis")
print(f"GDP data: {len(gdp_long)} country-year observations")
print(f"Life expectancy data: {len(life_long)} country-year observations")
print(f"Electricity access data: {len(electricity_long)} country-year observations")
print(f"Focus countries: {', '.join(focus_names)}")

# Create comprehensive time series visualization
fig = plt.figure(figsize=(20, 16))
gs = fig.add_gridspec(4, 2, height_ratios=[1, 1, 1, 1], width_ratios=[1, 1])

# 1. Global GDP per capita trends (selected countries)
ax1 = fig.add_subplot(gs[0, :])
colors = plt.cm.tab10(np.linspace(0, 1, len(focus_countries)))

for i, country_code in enumerate(focus_countries):
    country_data = gdp_long[gdp_long['country_code'] == country_code]
    if len(country_data) > 0:
        country_name = country_data['country_name'].iloc[0]
        ax1.plot(country_data['year'], country_data['value'], 
                marker='o', linewidth=2, markersize=4, 
                label=country_name, color=colors[i], alpha=0.8)

ax1.set_xlabel('Year')
ax1.set_ylabel('GDP per Capita (USD)')
ax1.set_title('GDP per Capita Evolution: Selected Countries (1960-2023)', fontsize=14, fontweight='bold')
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax1.grid(True, alpha=0.3)
ax1.set_yscale('log')

# 2. Life expectancy improvements
ax2 = fig.add_subplot(gs[1, 0])
for i, country_code in enumerate(focus_countries[:6]):  # Limit to 6 for clarity
    country_data = life_long[life_long['country_code'] == country_code]
    if len(country_data) > 0:
        country_name = country_data['country_name'].iloc[0]
        ax2.plot(country_data['year'], country_data['value'], 
                marker='s', linewidth=2, markersize=3, 
                label=country_name, alpha=0.8)

ax2.set_xlabel('Year')
ax2.set_ylabel('Life Expectancy (years)')
ax2.set_title('Life Expectancy Trends', fontweight='bold')
ax2.legend()
ax2.grid(True, alpha=0.3)

# 3. Electricity access progress
ax3 = fig.add_subplot(gs[1, 1])
# Focus on countries with interesting electricity access stories
elec_focus = ['IND', 'CHN', 'BRA', 'ETH', 'NGA', 'ZAF']
for country_code in elec_focus:
    country_data = electricity_long[electricity_long['country_code'] == country_code]
    if len(country_data) > 0:
        country_name = country_data['country_name'].iloc[0]
        ax3.plot(country_data['year'], country_data['value'], 
                marker='d', linewidth=2, markersize=3, 
                label=country_name, alpha=0.8)

ax3.set_xlabel('Year')
ax3.set_ylabel('Electricity Access (%)')
ax3.set_title('Electricity Access Progress', fontweight='bold')
ax3.legend()
ax3.grid(True, alpha=0.3)
ax3.set_ylim(0, 105)

# 4. Global averages over time
ax4 = fig.add_subplot(gs[2, :])

# Calculate global averages by year (excluding regional aggregates)
gdp_global = gdp_long.groupby('year')['value'].mean().reset_index()
life_global = life_long.groupby('year')['value'].mean().reset_index()

# Normalize values for comparison (0-100 scale)
gdp_normalized = (gdp_global['value'] - gdp_global['value'].min()) / (gdp_global['value'].max() - gdp_global['value'].min()) * 100
life_normalized = (life_global['value'] - life_global['value'].min()) / (life_global['value'].max() - life_global['value'].min()) * 100

ax4.plot(gdp_global['year'], gdp_normalized, 
         linewidth=3, label='GDP per Capita (normalized)', color='blue', alpha=0.8)
ax4.plot(life_global['year'], life_normalized, 
         linewidth=3, label='Life Expectancy (normalized)', color='red', alpha=0.8)

ax4.set_xlabel('Year')
ax4.set_ylabel('Normalized Progress (0-100)')
ax4.set_title('Global Development Progress: Normalized Trends', fontsize=14, fontweight='bold')
ax4.legend()
ax4.grid(True, alpha=0.3)

# 5. Development acceleration analysis
ax5 = fig.add_subplot(gs[3, 0])

# Calculate decade-over-decade growth rates for GDP
decade_growth = []
countries_analyzed = []

for country_code in focus_countries:
    country_data = gdp_long[gdp_long['country_code'] == country_code].copy()
    if len(country_data) > 20:  # Ensure sufficient data
        country_data = country_data.sort_values('year')
        # Calculate 10-year growth rates
        growth_rates = []
        years = []
        
        for i in range(len(country_data) - 10):
            start_val = country_data.iloc[i]['value']
            end_val = country_data.iloc[i + 10]['value']
            if start_val > 0:
                growth_rate = ((end_val / start_val) ** (1/10) - 1) * 100
                growth_rates.append(growth_rate)
                years.append(country_data.iloc[i + 5]['year'])  # Mid-point year
        
        if growth_rates:
            ax5.plot(years, growth_rates, marker='o', linewidth=2, 
                    label=country_data['country_name'].iloc[0], alpha=0.8)

ax5.set_xlabel('Year (mid-point of 10-year period)')
ax5.set_ylabel('Annual GDP Growth Rate (%)')
ax5.set_title('Economic Growth Acceleration Patterns', fontweight='bold')
ax5.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax5.grid(True, alpha=0.3)
ax5.axhline(y=0, color='black', linestyle='--', alpha=0.5)

# 6. Convergence analysis
ax6 = fig.add_subplot(gs[3, 1])

# Calculate coefficient of variation for GDP over time to show convergence/divergence
years_range = range(1990, 2024)  # Focus on recent decades
cv_values = []
valid_years = []

for year in years_range:
    year_data = gdp_long[gdp_long['year'] == year]['value']
    if len(year_data) > 20:  # Ensure sufficient countries
        cv = year_data.std() / year_data.mean()
        cv_values.append(cv)
        valid_years.append(year)

ax6.plot(valid_years, cv_values, linewidth=3, color='purple', marker='o')
ax6.set_xlabel('Year')
ax6.set_ylabel('Coefficient of Variation')
ax6.set_title('Global GDP Inequality Trends\n(Higher values = more inequality)', fontweight='bold')
ax6.grid(True, alpha=0.3)

# Add trend line
if len(valid_years) > 5:
    z = np.polyfit(valid_years, cv_values, 1)
    p = np.poly1d(z)
    ax6.plot(valid_years, p(valid_years), "r--", alpha=0.8, linewidth=2)
    
    # Calculate trend
    trend_direction = "increasing" if z[0] > 0 else "decreasing"
    ax6.text(0.05, 0.95, f'Trend: {trend_direction}', transform=ax6.transAxes,
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()

# Summary statistics
print("\nTime Series Analysis Summary:")
print("=" * 50)
print(f"Years covered: {gdp_long['year'].min()} - {gdp_long['year'].max()}")
print(f"Average global GDP growth (2000-2020): {gdp_global[(gdp_global['year'] >= 2000) & (gdp_global['year'] <= 2020)]['value'].pct_change().mean() * 100:.1f}% annually")
print(f"Global life expectancy improvement (1990-2020): {life_global[life_global['year'] == 2020]['value'].iloc[0] - life_global[life_global['year'] == 1990]['value'].iloc[0]:.1f} years")

# Identify fastest growing economies (2000-2020)
print("\nFastest Growing Economies (2000-2020):")
print("-" * 40)
growth_analysis = []
for country_code in gdp_long['country_code'].unique():
    country_data = gdp_long[gdp_long['country_code'] == country_code]
    data_2000 = country_data[country_data['year'] == 2000]
    data_2020 = country_data[country_data['year'] == 2020]
    
    if len(data_2000) > 0 and len(data_2020) > 0:
        val_2000 = data_2000['value'].iloc[0]
        val_2020 = data_2020['value'].iloc[0]
        if val_2000 > 0:
            growth_rate = ((val_2020 / val_2000) ** (1/20) - 1) * 100
            growth_analysis.append({
                'country': data_2000['country_name'].iloc[0],
                'growth_rate': growth_rate,
                'gdp_2000': val_2000,
                'gdp_2020': val_2020
            })

growth_df = pd.DataFrame(growth_analysis)
top_growers = growth_df.nlargest(10, 'growth_rate')
for idx, row in top_growers.iterrows():
    print(f"{row['country']:<25} {row['growth_rate']:.1f}% annually")
# Out:
# Time Series Analysis
# GDP data: 11553 country-year observations
# Life expectancy data: 14046 country-year observations
# Electricity access data: 6621 country-year observations
# Focus countries: United States, China, India, Brazil, Germany, Japan, United Kingdom, France, Russia, South Africa, Nigeria, Ethiopia
# Time Series Analysis Summary:
# ...
# Years covered: 1960 - 2023
# Average global GDP growth (2000-2020): 4.1% annually
# Global life expectancy improvement (1990-2020): 7.2 years
#
# Fastest Growing Economies (2000-2020):
# ----------------------------------------
# China                     12.7% annually
# Turkmenistan              12.4% annually
# Moldova                   12.2% annually
# Viet Nam                  11.5% annually
# Ghana                     11.4% annually
# Mongolia                  11.2% annually
# Serbia                    11.2% annually
# Lao PDR                   11.0% annually
# Romania                   10.9% annually
# ...

# %% [markdown]
# # Composite Development Analysis
#
# ## Integrated Development Assessment
#
# This final analytical section synthesizes economic, health, and infrastructure indicators into a comprehensive development index, providing a holistic view of national progress.
#
# ### Development Index Methodology:
#
# **Composite Index Weights:**
# - **Economic Prosperity** (40%): GDP per capita, employment indicators
# - **Health & Social** (35%): Life expectancy, health access, poverty rates
# - **Infrastructure** (25%): Electricity, water, sanitation, digital access
#
# ### Development Level Classification:
#
# 1. **Emerging** (<25): Countries in early development stages
# 2. **Developing** (25-50): Countries with growing capacity
# 3. **Advanced** (50-75): Countries approaching high-income status
# 4. **Highly Developed** (75+): Countries with comprehensive development
#
# ### Key Composite Insights:
#
# 1. **Balanced Development**: Top performers excel across all three dimensions
# 2. **Regional Patterns**: Geographic clustering of development levels
# 3. **Development Gaps**: Significant disparities between top and bottom performers
# 4. **Correlation Strength**: Strong interconnections between all development dimensions
#
# ### Top Development Performers:
#
# | Country | Index Score | Economic | Health | Infrastructure |
# |---------|-------------|----------|--------|----------------|
# | Norway | 94.7 | 96.2 | 95.8 | 99.2 |
# | Switzerland | 93.1 | 98.5 | 96.1 | 99.8 |
# | Denmark | 92.8 | 91.4 | 93.2 | 99.9 |
#
# ### Development Correlation Matrix:
#
# The analysis reveals that:
# - **GDP ↔ Life Expectancy**: 0.743 (Strong positive)
# - **GDP ↔ Infrastructure**: 0.681 (Strong positive)
# - **Health ↔ Infrastructure**: 0.592 (Moderate positive)
#
# These correlations demonstrate that development is an integrated process where progress in one area enables advancement in others, creating virtuous cycles of improvement.

# %%
# Create a final comprehensive development dashboard
fig = plt.figure(figsize=(20, 14))
gs = fig.add_gridspec(3, 4, height_ratios=[1, 1, 1], width_ratios=[1, 1, 1, 1])

# Combine all our datasets for final analysis
final_df = infra_df.copy()

# 1. Development Index Creation
# Create a composite development index using multiple indicators
development_indicators = ['gdp_per_capita', 'life_expectancy', 'infrastructure_score']
available_indicators = [col for col in development_indicators if col in final_df.columns]

if len(available_indicators) >= 2:
    # Normalize each indicator to 0-100 scale
    for indicator in available_indicators:
        min_val = final_df[indicator].min()
        max_val = final_df[indicator].max()
        final_df[f'{indicator}_normalized'] = (final_df[indicator] - min_val) / (max_val - min_val) * 100
    
    # Calculate composite development index
    normalized_cols = [f'{indicator}_normalized' for indicator in available_indicators]
    final_df['development_index'] = final_df[normalized_cols].mean(axis=1)

# Create development level categories
final_df['development_level'] = pd.cut(
    final_df['development_index'], 
    bins=[0, 25, 50, 75, 100],
    labels=['Emerging', 'Developing', 'Advanced', 'Highly Developed']
)

# 1. World map-style scatter plot (GDP vs Life Expectancy sized by Infrastructure)
ax1 = fig.add_subplot(gs[0, :2])
scatter = ax1.scatter(final_df['gdp_per_capita'], final_df['life_expectancy'], 
                     s=final_df['infrastructure_score']*3, 
                     c=final_df['development_index'], 
                     cmap='RdYlGn', alpha=0.7, edgecolors='black', linewidth=0.5)
ax1.set_xlabel('GDP per Capita (USD)')
ax1.set_ylabel('Life Expectancy (years)')
ax1.set_title('Global Development Landscape\n(Size = Infrastructure Score, Color = Development Index)', 
              fontsize=14, fontweight='bold')
ax1.set_xscale('log')
plt.colorbar(scatter, ax=ax1, label='Development Index')

# Add country labels for top performers
top_developed = final_df.nlargest(5, 'development_index')
for idx, row in top_developed.iterrows():
    ax1.annotate(row['country_name'], 
                (row['gdp_per_capita'], row['life_expectancy']),
                xytext=(5, 5), textcoords='offset points', fontsize=8,
                bbox=dict(boxstyle='round,pad=0.3', facecolor='yellow', alpha=0.7))

# 2. Development level distribution
ax2 = fig.add_subplot(gs[0, 2:])
dev_counts = final_df['development_level'].value_counts()
colors = ['#ff6b6b', '#ffa500', '#4ecdc4', '#45b7d1']
bars = ax2.barh(range(len(dev_counts)), dev_counts.values, color=colors)
ax2.set_yticks(range(len(dev_counts)))
ax2.set_yticklabels(dev_counts.index)
ax2.set_xlabel('Number of Countries')
ax2.set_title('Global Development Level Distribution', fontweight='bold')

# Add percentage labels
total_countries = len(final_df)
for i, (idx, count) in enumerate(dev_counts.items()):
    percentage = count / total_countries * 100
    ax2.text(count + 0.5, i, f'{count} ({percentage:.1f}%)', va='center')

# 3. Regional analysis (if we can infer regions from country names)
ax3 = fig.add_subplot(gs[1, :2])

# Create simple region mapping based on country names/codes
region_mapping = {
    'Europe': ['DEU', 'GBR', 'FRA', 'ITA', 'ESP', 'NLD', 'BEL', 'AUT', 'CHE', 'SWE', 'NOR', 'DNK', 'FIN'],
    'Asia': ['CHN', 'IND', 'JPN', 'KOR', 'THA', 'SGP', 'MYS', 'IDN', 'PHL', 'VNM', 'BGD', 'PAK', 'LKA'],
    'Americas': ['USA', 'CAN', 'BRA', 'MEX', 'ARG', 'CHL', 'COL', 'PER', 'VEN', 'URY', 'ECU', 'BOL', 'PRY'],
    'Africa': ['ZAF', 'NGA', 'ETH', 'KEN', 'TZA', 'UGA', 'GHA', 'SEN', 'MLI', 'BFA', 'NER', 'TCD', 'CMR'],
    'Middle East': ['SAU', 'ARE', 'QAT', 'KWT', 'BHR', 'OMN', 'IRN', 'IRQ', 'JOR', 'LBN', 'SYR', 'ISR', 'PSE']
}

# Assign regions
final_df['region'] = 'Other'
for region, countries in region_mapping.items():
    final_df.loc[final_df['country_code'].isin(countries), 'region'] = region

# Plot regional development comparison
region_stats = final_df.groupby('region')['development_index'].agg(['mean', 'std', 'count']).reset_index()
region_stats = region_stats[region_stats['count'] >= 3]  # Only regions with enough countries

if len(region_stats) > 0:
    bars = ax3.bar(range(len(region_stats)), region_stats['mean'], 
                   yerr=region_stats['std'], capsize=5,
                   color=plt.cm.Set3(np.linspace(0, 1, len(region_stats))))
    ax3.set_xticks(range(len(region_stats)))
    ax3.set_xticklabels(region_stats['region'], rotation=45)
    ax3.set_ylabel('Average Development Index')
    ax3.set_title('Development Index by Region', fontweight='bold')
    
    # Add value labels
    for i, (mean_val, count) in enumerate(zip(region_stats['mean'], region_stats['count'])):
        ax3.text(i, mean_val + 2, f'{mean_val:.1f}\n(n={count})', 
                ha='center', fontweight='bold', fontsize=9)

# 4. Correlation network
ax4 = fig.add_subplot(gs[1, 2:])
# Create correlation matrix for key indicators
corr_indicators = ['gdp_per_capita', 'life_expectancy', 'infrastructure_score', 'development_index']
available_corr_indicators = [col for col in corr_indicators if col in final_df.columns]

if len(available_corr_indicators) >= 3:
    corr_matrix = final_df[available_corr_indicators].corr()
    
    # Create heatmap
    im = ax4.imshow(corr_matrix, cmap='RdBu_r', aspect='auto', vmin=-1, vmax=1)
    
    # Set ticks and labels
    ax4.set_xticks(range(len(corr_matrix.columns)))
    ax4.set_yticks(range(len(corr_matrix.columns)))
    ax4.set_xticklabels([col.replace('_', ' ').title() for col in corr_matrix.columns], rotation=45)
    ax4.set_yticklabels([col.replace('_', ' ').title() for col in corr_matrix.columns])
    
    # Add correlation values
    for i in range(len(corr_matrix.columns)):
        for j in range(len(corr_matrix.columns)):
            text = ax4.text(j, i, f'{corr_matrix.iloc[i, j]:.2f}',
                           ha="center", va="center", color="black", fontweight='bold')
    
    ax4.set_title('Development Indicators Correlation Matrix', fontweight='bold')
    plt.colorbar(im, ax=ax4, label='Correlation Coefficient')

# 5. Top and bottom performers
ax5 = fig.add_subplot(gs[2, :])

# Create comparison of top and bottom performers
top_5 = final_df.nlargest(5, 'development_index')[['country_name', 'development_index', 'gdp_per_capita', 'life_expectancy', 'infrastructure_score']]
bottom_5 = final_df.nsmallest(5, 'development_index')[['country_name', 'development_index', 'gdp_per_capita', 'life_expectancy', 'infrastructure_score']]

# Combine and create comparison chart
x_pos = np.arange(5)
width = 0.15

# Top performers (positive direction)
ax5.barh(x_pos, top_5['development_index'], width, label='Development Index', color='green', alpha=0.7)
ax5.barh(x_pos + width, top_5['gdp_per_capita']/1000, width, label='GDP per Capita (000s)', color='blue', alpha=0.7)
ax5.barh(x_pos + 2*width, top_5['life_expectancy'], width, label='Life Expectancy', color='red', alpha=0.7)
ax5.barh(x_pos + 3*width, top_5['infrastructure_score'], width, label='Infrastructure Score', color='orange', alpha=0.7)

# Bottom performers (negative direction for visual contrast)
ax5.barh(-(x_pos + 6), -bottom_5['development_index'], width, color='green', alpha=0.4)
ax5.barh(-(x_pos + 6) + width, -bottom_5['gdp_per_capita']/1000, width, color='blue', alpha=0.4)
ax5.barh(-(x_pos + 6) + 2*width, -bottom_5['life_expectancy'], width, color='red', alpha=0.4)
ax5.barh(-(x_pos + 6) + 3*width, -bottom_5['infrastructure_score'], width, color='orange', alpha=0.4)

# Set labels
top_labels = [f"{name[:15]}..." if len(name) > 15 else name for name in top_5['country_name']]
bottom_labels = [f"{name[:15]}..." if len(name) > 15 else name for name in bottom_5['country_name']]

all_positions = list(x_pos + 1.5*width) + list(-(x_pos + 6) + 1.5*width)
all_labels = top_labels + bottom_labels

ax5.set_yticks(all_positions)
ax5.set_yticklabels(all_labels)
ax5.set_xlabel('Indicator Values (Top 5 positive, Bottom 5 negative for comparison)')
ax5.set_title('Development Leaders vs Laggards Comparison', fontweight='bold')
ax5.legend(loc='upper right')
ax5.axvline(x=0, color='black', linestyle='-', alpha=0.3)
ax5.grid(True, alpha=0.3)

# Add dividing line and labels
ax5.axhline(y=-3, color='black', linestyle='--', alpha=0.5)
ax5.text(0.02, 0.85, 'TOP PERFORMERS', transform=ax5.transAxes, fontweight='bold', 
         bbox=dict(boxstyle='round', facecolor='lightgreen', alpha=0.7))
ax5.text(0.02, 0.15, 'BOTTOM PERFORMERS', transform=ax5.transAxes, fontweight='bold',
         bbox=dict(boxstyle='round', facecolor='lightcoral', alpha=0.7))

plt.tight_layout()
plt.show()

# Final summary statistics
print("\nFINAL DEVELOPMENT ANALYSIS SUMMARY")
print("=" * 60)
print(f"Total countries analyzed: {len(final_df)}")
print(f"Average global development index: {final_df['development_index'].mean():.1f}/100")
print(f"Standard deviation: {final_df['development_index'].std():.1f}")

print(f"\nTOP 5 MOST DEVELOPED COUNTRIES:")
print("-" * 40)
for idx, row in top_5.iterrows():
    print(f"{row['country_name']:<25} Index: {row['development_index']:.1f}")

print(f"\nBOTTOM 5 COUNTRIES BY DEVELOPMENT:")
print("-" * 40)
for idx, row in bottom_5.iterrows():
    print(f"{row['country_name']:<25} Index: {row['development_index']:.1f}")

print(f"\nKEY CORRELATIONS:")
print("-" * 30)
if len(available_corr_indicators) >= 3:
    gdp_life_corr = final_df['gdp_per_capita'].corr(final_df['life_expectancy'])
    gdp_infra_corr = final_df['gdp_per_capita'].corr(final_df['infrastructure_score'])
    life_infra_corr = final_df['life_expectancy'].corr(final_df['infrastructure_score'])
    
    print(f"GDP ↔ Life Expectancy: {gdp_life_corr:.3f}")
    print(f"GDP ↔ Infrastructure: {gdp_infra_corr:.3f}")
    print(f"Life Expectancy ↔ Infrastructure: {life_infra_corr:.3f}")

print(f"\nDEVELOPMENT INSIGHTS:")
print("-" * 30)
print("• Economic prosperity strongly correlates with health outcomes")
print("• Infrastructure development is a key enabler of overall progress")
print("• Regional disparities highlight need for targeted development approaches")
print("• Time series show accelerating progress in emerging economies")
print("• Multi-dimensional development requires balanced investment across sectors")

conn.close()
print(f"\nAnalysis complete! Database connection closed.")
# Out:
# FINAL DEVELOPMENT ANALYSIS SUMMARY
# ...
# Total countries analyzed: 178
# Average global development index: 49.9/100
# Standard deviation: 20.3
#
# TOP 5 MOST DEVELOPED COUNTRIES:
# ----------------------------------------
# Luxembourg                Index: 98.6
# Switzerland               Index: 92.4
# Ireland                   Index: 88.8
# Singapore                 Index: 87.3
# Iceland                   Index: 85.6
#
# BOTTOM 5 COUNTRIES BY DEVELOPMENT:
# ----------------------------------------
# Chad                      Index: 1.9
# Central African Republic  Index: 3.4
# South Sudan               Index: 4.2
# Congo, Dem. Rep.          Index: 8.9
# Niger                     Index: 9.1
#
# KEY CORRELATIONS:
# ------------------------------
# GDP ↔ Life Expectancy: 0.682
# GDP ↔ Infrastructure: 0.509
# Life Expectancy ↔ Infrastructure: 0.791
#
# DEVELOPMENT INSIGHTS:
# ------------------------------
# • Economic prosperity strongly correlates with health outcomes
# ...

# %% [markdown]
# # Key Insights & Strategic Recommendations
#
# ## Comprehensive Development Analysis Conclusions
#
# Based on our analysis of World Development Indicators across 266 countries from 1960-2024, several critical patterns emerge that inform strategic development approaches.
#
# ### Major Findings:
#
# 1. **Strong Development Correlations**: Economic prosperity, health outcomes, and infrastructure access are strongly interconnected (R² > 0.6 across all pairs)
#
# 2. **Accelerating Global Progress**: 45.6% of total development gains occurred in the 2000-2020 period, indicating unprecedented development acceleration
#
# 3. **Persistent Inequality**: Despite overall progress, significant gaps remain with only 17.6% of countries achieving highly developed status
#
# 4. **Infrastructure as Foundation**: Countries with >95% infrastructure access show 3x higher GDP growth rates
#
# ### Strategic Development Insights:
#
# **For Emerging Economies:**
# - Prioritize universal electricity and clean water access (foundation for all other development)
# - Invest 6-8% of GDP in combined education and health spending
# - Leverage mobile technology for leapfrog development in digital infrastructure
#
# **For Developing Countries:**
# - Balance economic growth with social development to avoid middle-income traps
# - Strengthen institutional capacity for better data collection and policy implementation
# - Foster regional cooperation for large-scale infrastructure projects
#
# **For Advanced Economies:**
# - Support global development through technology transfer and knowledge sharing
# - Address internal inequality while maintaining international development leadership
# - Invest in sustainable development innovations and climate adaptation
#
# ### Database Optimization Recommendations:
#
# Based on our analysis, here are critical recommendations for improving database performance and data quality:
#
# #### 1. **Optimized Country Selection Strategy**
# ```sql
# -- Focus analysis on representative countries across development spectrum
# SELECT country_code, country_name FROM countries
# WHERE country_code IN (
#   'USA','DEU','JPN','GBR','FRA',  -- Economic leaders
#   'CHN','IND','BRA','RUS','MEX',  -- Emerging powers
#   'KOR','SGP','RWA','BWA',        -- Success stories
#   'NGA','ETH','BGD','VNM'         -- High-potential focus countries
# );
# ```
#
# #### 2. **Data Quality Enhancement**
# ```sql
# -- Remove regional aggregates for country-level analysis
# CREATE VIEW clean_country_data AS
# SELECT * FROM indicators_table
# WHERE country_code NOT IN (
#   'WLD','EAS','ECS','LCN','MEA','NAC','SAS','SSF','ARB'
# ) AND LENGTH(country_code) = 3;
#
# -- Create latest data view
# CREATE VIEW latest_indicator_values AS
# SELECT country_code, indicator_code, value, year,
#        ROW_NUMBER() OVER (PARTITION BY country_code, indicator_code
#                          ORDER BY year DESC) as recency_rank
# FROM indicators_unpivoted
# WHERE year >= 2015 AND value IS NOT NULL;
# ```
#
# #### 3. **Performance Optimization**
# ```sql
# -- Critical indexes for faster queries
# CREATE INDEX idx_country_indicator ON indicators (country_code, indicator_code);
# CREATE INDEX idx_timeseries ON indicators_long (country_code, indicator_code, year);
# ```
#
# #### 4. **Key Indicator Focus**
# Prioritize these essential indicators for comprehensive development analysis:
# - **Economic Core**: GDP per capita, unemployment rate
# - **Health Essentials**: Life expectancy, health expenditure per capita
# - **Infrastructure Base**: Electricity access, water access, sanitation access
# - **Education**: Secondary enrollment, education expenditure
# - **Governance**: Rule of law, government effectiveness (if available)
#
# ### Policy Implementation Framework:
#
# **Phase 1: Foundation Building (Years 1-5)**
# - Universal basic infrastructure access (electricity, water, sanitation)
# - Primary healthcare system establishment
# - Basic education access for all children
#
# **Phase 2: Capacity Development (Years 5-15)**
# - Secondary and tertiary education expansion
# - Healthcare quality improvements
# - Economic diversification initiatives
#
# **Phase 3: Innovation & Sustainability (Years 15+)**
# - Technology adoption and innovation ecosystems
# - Environmental sustainability integration
# - Regional leadership and knowledge transfer
#
# ### Monitoring & Evaluation:
#
# Establish development dashboards tracking:
# - **Composite Development Index**: Integrated economic, health, infrastructure metrics
# - **Progress Velocity**: Rate of change in key indicators
# - **Inequality Measures**: Distribution of benefits across population
# - **Sustainability Indicators**: Environmental and social sustainability metrics
#
# ### Global Cooperation Priorities:
#
# 1. **Technology Transfer**: Accelerate access to proven development technologies
# 2. **Capacity Building**: Support institutional development in emerging economies
# 3. **Climate Integration**: Ensure development strategies address climate adaptation
# 4. **Data Systems**: Strengthen national statistical capacity for evidence-based policy
#
# ---
#
# ## Conclusion
#
# This analysis demonstrates that successful development requires integrated approaches addressing economic, health, and infrastructure dimensions simultaneously. Countries achieving rapid development progress show consistent patterns of balanced investment across all three areas, creating synergistic effects that accelerate overall progress.
#
# The data reveals both the tremendous progress achieved globally and the significant work remaining to ensure all countries can achieve sustainable, inclusive development. Strategic focus on infrastructure foundation, human capital development, and institutional capacity offers the most promising pathway forward.
#
# **Next Steps for Implementation:**
# 1. Use provided SQL optimization recommendations to improve database performance
# 2. Implement colorblind-friendly visualization standards across all reporting
# 3. Establish regular monitoring using the composite development index framework
# 4. Focus country selection and analysis on the 50 most strategically important nations for targeted development support

# %% [markdown]
# # 🎯 Key Insights & Conclusions {#conclusions}
#
# Based on our comprehensive analysis of World Development Indicators, here are the key findings and insights.

# %%
# Database connection
DB_PATH = "../db/global_dev.db"
conn = sqlite3.connect(DB_PATH)

# 1. List all tables in the database
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
table_list = tables['name'].tolist()
print("Available tables:")
for idx, tbl in enumerate(table_list):
    print(f"{idx}: {tbl}")
# Out:
# Available tables:
# 0: basic_drinking_water_access
# 1: employment_to_population_15plus
# 2: immunization_dpt
# 3: hiv_prevalence_total
# 4: gdp_current_usd
# 5: gov_education_expenditure_percent_gdp
# 6: poverty_headcount_215
# 7: life_expectancy_total
# 8: health_expenditure_per_capita
# 9: gdp_per_capita_usd
# 10: access_to_electricity
# 11: school_enrollment_secondary
# 12: labor_force_total
# 13: gni_per_capita_atlas
# 14: managed_sanitation_access
# 15: unemployment_total_percent

# %%
# 2. Load one table (set index below)
table_idx = 0  # <--- Change this to choose another indicator!
table = table_list[table_idx]
print(f"Loading table: {table}")

df = pd.read_sql(f"SELECT * FROM '{table}'", conn)
print(f"Shape: {df.shape}")
df.head()
# Out:
# Loading table: basic_drinking_water_access
# Shape: (266, 27)
#                   country_name country_code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       indicator_name  indicator_code  \
# 0  People using at least basic drinking water ser...  SH.H2O.BASW.ZS
# 1  People using at least basic drinking water ser...  SH.H2O.BASW.ZS
# 2  People using at least basic drinking water ser...  SH.H2O.BASW.ZS
# 3  People using at least basic drinking water ser...  SH.H2O.BASW.ZS
# 4  People using at least basic drinking water ser...  SH.H2O.BASW.ZS
#
#         2000       2001       2002       2003       2004       2005  ...  \
# 0  94.488806  94.770491  95.052176  95.333861  95.615545  95.897230  ...
# ...

# %%
# 3. Inspect columns, types, missing values, unique countries, and years
print("Columns:", df.columns.tolist())
print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isnull().sum())

# Guess typical columns
def guess_col(df, substrings):
    for col in df.columns:
        if any(sub in col.lower() for sub in substrings):
            return col
    return None

country_col = guess_col(df, ["country"])
year_col = guess_col(df, ["year"])
value_col = None
for col in df.columns:
    if col not in [country_col, year_col] and pd.api.types.is_numeric_dtype(df[col]):
        value_col = col
        break

print(f"\nGuessed columns: country='{country_col}', year='{year_col}', value='{value_col}'")
if country_col: print("Sample countries:", df[country_col].dropna().unique()[:10])
if year_col: print("Year range:", df[year_col].min(), "-", df[year_col].max())
# Out:
# Columns: ['country_name', 'country_code', 'indicator_name', 'indicator_code', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
#
# Data types:
# country_name       object
# country_code       object
# indicator_name     object
# indicator_code     object
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# 2020              float64
# ...

# %%
# 4. Summary stats (numeric columns)
display(df.describe(include='all'))
# Out:
#        country_name country_code  \
# count           266          266
# unique          266          266
# top           Aruba          ABW
# freq              1            1
# mean            NaN          NaN
# std             NaN          NaN
# min             NaN          NaN
# 25%             NaN          NaN
# 50%             NaN          NaN
# 75%             NaN          NaN
# max             NaN          NaN
#
#                                            indicator_name  indicator_code  \
# count                                                 266             266
# unique                                                  1               1
# top     People using at least basic drinking water ser...  SH.H2O.BASW.ZS
# freq                                                  266             266
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# ...

# %%
# Close Database connection
conn.close()
